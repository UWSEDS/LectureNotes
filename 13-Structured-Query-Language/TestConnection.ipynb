# %%
# loading the special sql extension
# %load_ext sql
# Out:
# The sql extension is already loaded. To reload it, use:
#   %reload_ext sql

# %%
# connecting to a database which lives on the Amazon Cloud
# need to substitute password with the one provided in the email!!!
# %sql postgresql://dssg_student:password@seds-sql.csya4zsfb6y4.us-east-1.rds.amazonaws.com/dssg2016
# Out:
# 'Connected: dssg_student@dssg2016'

# %%
# running a simple SQL command
# %sql select * from seattlecrimeincidents limit 10;
# Out:
# 10 rows affected.
# [(None, 18, 'DISPUTE-OTH', None, 'DISPUTE', datetime.datetime(2015, 1, 26, 13, 25), datetime.datetime(2015, 1, 25, 20, 0), datetime.datetime(2015, 1, 25, 20, 0), 'MAYNARD AV S / S LUCILE ST', 'O', 'O2', 10900.2042, -122.3253949, 47.55337429, 1, 2015, 56, '0101000020E610000041722145D3945EC0A5FFFEF7D4C64740', '0101000020850E0000979B9D69C6CE20419081F48370175441'),
#  (None, 21, 'DISTURBANCE-OTH', None, 'DISTURBANCE', datetime.datetime(2015, 1, 29, 14, 32), datetime.datetime(2015, 1, 29, 14, 29), None, '20XX BLOCK OF 5 AV', 'M', 'M2', 7200.1058, -122.3398236, 47.61411132, 1, 2015, 1067, '0101000020E61000002D1A7CABBF955EC06FC021339BCE4740', '0101000020850E0000D749456FD8C52041068E86B7051E5441'),
#  (None, 21, 'DISTURBANCE-OTH', None, 'DISTURBANCE', datetime.datetime(2015, 1, 22, 4, 35), datetime.datetime(2015, 1, 22, 4, 35), None, '105XX BLOCK OF AURORA AV N', 'N', 'N3', 1300.2002, -122.3447064, 47.70579857, 1, 2015, 468, '0101000020E610000034AE6EAB0F965EC056DB879B57DA4740', '0101000020850E00009ABDE7414EC220416114B96FF8275441'),
#  (None, 21, 'DISTURBANCE-OTH', None, 'DISTURBANCE', datetime.datetime(2015, 1, 17, 1, 21), datetime.datetime(2015, 1, 17, 1, 21), None, 'NW 100 ST / 12 AV NW', 'N', 'N1', 1400.4013, -122.3714156, 47.70152724, 1, 2015, 976, '0101000020E61000005ACEEF45C5975EC0CD8604A5CBD94740', '0101000020850E00003D8C439CAEB22041891D459B7D275441'),
#  ('1313', 0, 'ASSLT-NONAGG', '1300', 'ASSAULT', datetime.datetime(2015, 2, 2, 6, 48), datetime.datetime(2015, 2, 2, 6, 48), None, '3XX BLOCK OF 9 AV', 'G', 'G1', 8500.3001, -122.3234439, 47.60412808, 2, 2015, 1268, '0101000020E6100000CE250B4EB3945EC0FF18A51154CD4740', '0101000020850E0000754B04A589CF2041895883FDF21C5441'),
#  (None, 21, 'DISTURBANCE-OTH', None, 'DISTURBANCE', datetime.datetime(2015, 1, 17, 1, 49), datetime.datetime(2015, 1, 17, 1, 45), None, '22XX BLOCK OF 2 AV', 'D', 'D1', 8001.2009, -122.3450035, 47.6136555, 1, 2015, 1398, '0101000020E61000005B608F8914965EC059C16F438CCE4740', '0101000020850E0000619840C1CEC22041213B293AF81D5441'),
#  (None, 47, 'PROPERTY FOUND', None, 'STOLEN PROPERTY', datetime.datetime(2015, 1, 21, 5, 28), datetime.datetime(2015, 1, 4, 0, 0), None, '8XX BLOCK OF VIRGINIA ST', 'D', 'D2', 7300.3022, -122.3361655, 47.6160533, 1, 2015, 1507, '0101000020E6100000C9224DBC83955EC0E30BA4D5DACE4740', '0101000020850E00000449DC8CFAC7204114C89E423C1E5441'),
#  ('1313', 0, 'ASSLT-NONAGG', '1300', 'ASSAULT', datetime.datetime(2015, 2, 5, 20, 59), datetime.datetime(2015, 2, 5, 19, 31), None, '15 AV NW / NW MARKET ST', 'B', 'B1', 4700.302, -122.3762156, 47.6686649, 2, 2015, 1582, '0101000020E6100000AE8F98EA13985EC0D7BDBACF96D54740', '0101000020850E0000C5414D2F19B0204194E04FCEEB235441'),
#  (None, 47, 'PROPERTY FOUND', None, 'STOLEN PROPERTY', datetime.datetime(2015, 2, 10, 17, 5), datetime.datetime(2015, 2, 10, 17, 5), None, '1XX BLOCK OF BELMONT AV E', 'E', 'E1', 7402.1007, -122.324008, 47.61907482, 2, 2015, 2538, '0101000020E61000001DE90C8CBC945EC0ABD6FCD73DCF4740', '0101000020850E000089F479E417CF2041694D1F2F921E5441'),
#  ('1313', 0, 'ASSLT-NONAGG', '1300', 'ASSAULT', datetime.datetime(2015, 2, 11, 6, 59), datetime.datetime(2015, 2, 11, 6, 59), None, '5XX BLOCK OF 3 AV', 'K', 'K2', 8100.2043, -122.3310822, 47.60241242, 2, 2015, 2630, '0101000020E61000006A52657330955EC0574DA5D91BCD4740', '0101000020850E00004F88F1AE10CB204190E9BE13C21C5441')]
